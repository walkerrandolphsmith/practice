# %% [markdown]
# # Visual Data
#
# Gain insights into and improve your analysis by visualizing data
#
# # Setup
# 1. Install anaconda
# 2. Add anaconda to path
# 3. Install jupyter notebook vscode extension.
# 4. Configure kernel to be the version of python installed in the anaconda directory

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x_vector = np.linspace(-10, 10, 100)
y_vector = np.sin(x_vector)
plt.plot(x_vector, y_vector, marker="x")
